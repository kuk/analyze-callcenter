# %%
# %matplotlib inline
# %run -n main.py

# %%
sounds = read_sounds()

# %% [markdown]
# # Диаризация

# %%
etalons = load_diarizations(format='{}_etalon.pickle')
segments = load_diarizations()

# %%
name = 'water'
plot_segments(sounds[name], segments[name], etalons[name])

# %%
name = 'mosenergo'
plot_segments(sounds[name], segments[name], etalons[name])

# %%
name = 'rigla'
plot_segments(sounds[name], segments[name], etalons[name])

# %%
name = 'transaero'
plot_segments(sounds[name], segments[name], etalons[name])

# %%
name = 'worldclass'
plot_segments(sounds[name], segments[name], etalons[name])

# %% [markdown]
# # Расшифровка

# %% [markdown]
# ## По эталонной диаризации

# %%
etalons = load_transcripts(format='{}_etalon.pickle')
transcripts = load_transcripts()

# %%
# %run -n main.py

# %%
name = 'water'
show_transcripts(transcripts[name], etalons[name])
# Out:
# <table style="border:0">
#   <tr style="border:0">
#     <td style="border:0">
#       —
#       Здравствуйте меня зовут ярослав чем
#
#       <span style="border-bottom:1px solid #f8481c">
#         я
#       </span>
#
#       могу помочь
#     </td>
#     <td style="border:0">
#       —
#       Здравствуйте меня зовут ярослав чем могу помочь
#     </td>
#   </tr>
#   <tr style="border:0">
#     <td style="border:0">
#       —
#       Добрый день меня зовут александр я хотел бы оформить подключить счетчики на воду
#     </td>
#     <td style="border:0">
#       —
#
#       <span style="border-bottom:1px solid #f8481c">
#         Да
#       </span>
#
#       добрый день меня зовут александр я хотел бы оформить подключить счётчики на воду
#     </td>
#   </tr>
#   <tr style="border:0">
#     <td style="border:0">
#       —
#
#       <span style="border-bottom:1px solid #f8481c">
#         3
#       </span>
#
#       сейчас уже
#
#       <span style="border-bottom:1px solid #f8481c">
# ...

# %%
name = 'mosenergo'
show_transcripts(transcripts[name], etalons[name])
# Out:
# <table style="border:0">
#   <tr style="border:0">
#     <td style="border:0">
#       —
#       Доброе утро меня зовут олеся
#     </td>
#     <td style="border:0">
#       —
#       Доброе утро меня зовут олеся
#
#       <span style="border-bottom:1px solid #f8481c">
#         я вас слушаю
#       </span>
#
#     </td>
#   </tr>
#   <tr style="border:0">
#     <td style="border:0">
#       —
#       Здрасте меня зовут александр я хотел бы узнать на сколько мне нужно заплатить за этот месяц денег потому что сейчас
#
#       <span style="border-bottom:1px solid #f8481c">
#         нам некуда
#       </span>
#
#       странно картину мне
#
#       <span style="border-bottom:1px solid #f8481c">
#         пришли 3 плата
#       </span>
#
#       за июнь я хотел сообщить
#     </td>
#     <td style="border:0">
#       —
#       Здрасте меня зовут александр я хотел бы узнать на сколько мне нужно заплатить за этот месяц денег потому что сейчас
#
# ...

# %%
name = 'rigla'
show_transcripts(transcripts[name], etalons[name])
# Out:
# <table style="border:0">
#   <tr style="border:0">
#     <td style="border:0">
#       —
#       Оператор анастасия слушала
#     </td>
#     <td style="border:0">
#       —
#       Оператор анастасия слушаю вас
#     </td>
#   </tr>
#   <tr style="border:0">
#     <td style="border:0">
#       —
#       Добрый вечер
#
#       <span style="border-bottom:1px solid #f8481c">
#         разрешены
#       </span>
#
#       хотел бы уточнить наличие лекарства в аптеке рядом
#     </td>
#     <td style="border:0">
#       —
#       Добрый вечер
#
#       <span style="border-bottom:1px solid #f8481c">
#         меня зовут александр
#       </span>
#
#       хотел бы уточнить наличие лекарства в аптеке рядом
#
#       <span style="border-bottom:1px solid #f8481c">
#         с
#       </span>
#
#     </td>
#   </tr>
#   <tr style="border:0">
#     <td style="border:0">
#       —
#
#       <span style="border-bottom:1px solid #f8481c">
#         После 40 лет
#       </span>
#
#     </td>
# ...

# %%
name = 'transaero'
show_transcripts(transcripts[name], etalons[name])
# Out:
# <table style="border:0">
#   <tr style="border:0">
#     <td style="border:0">
#       —
#
#       <span style="border-bottom:1px solid #f8481c">
#         Однако по некоторым данным
#       </span>
#
#       здравствуйте
#     </td>
#     <td style="border:0">
#       —
#
#       <span style="border-bottom:1px solid #f8481c">
#         Авиакомпания трансаэеро светлана
#       </span>
#
#       здравствуйте
#     </td>
#   </tr>
#   <tr style="border:0">
#     <td style="border:0">
#       —
#       Здравствуйте меня зовут александр
#
#       <span style="border-bottom:1px solid #f8481c">
#         чем
#       </span>
#
#       хотел узнать можно ли
#
#       <span style="border-bottom:1px solid #f8481c">
#         проводить там
#       </span>
#
#       груз рейс
#
#       <span style="border-bottom:1px solid #f8481c">
#         чуть чуть а
#       </span>
#
#     </td>
#     <td style="border:0">
#       —
#       Здравствуйте
#
# ...

# %%
name = 'worldclass'
show_transcripts(transcripts[name], etalons[name])
# Out:
# <table style="border:0">
#   <tr style="border:0">
#     <td style="border:0">
#       —
#
#       <span style="border-bottom:1px solid #f8481c">
#         Ворон красной
#       </span>
#
#       пресне
#
#       <span style="border-bottom:1px solid #f8481c">
#         людоеда
#       </span>
#
#       добрый вечер
#     </td>
#     <td style="border:0">
#       —
#
#       <span style="border-bottom:1px solid #f8481c">
#         Ворлдкласс на
#       </span>
#
#       пресне
#
#       <span style="border-bottom:1px solid #f8481c">
#         елизавета
#       </span>
#
#       добрый вечер
#     </td>
#   </tr>
#   <tr style="border:0">
#     <td style="border:0">
#       —
#
#       <span style="border-bottom:1px solid #f8481c">
#         Женщину
#       </span>
#
#       зовут александр я хотел бы посещать возможно ваш клуб пару вопросов есть
#
#       <span style="border-bottom:1px solid #f8481c">
#         опера
#       </span>
#
#     </td>
#     <td style="border:0">
#       —
# ...
