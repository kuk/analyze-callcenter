# %%
# %matplotlib inline
# %run -n main.py

# %%
sound = read_sound('sounds/rigla.wav')

# %%
sounds = read_sounds()

# %%
sound = sounds['rigla']

# %% [markdown]
# # Диаризация

# %%
# segments = diarize_sound(sound)
# dump_diarization(segments, 'segments/rigla.pickle')
segments = load_diarization('segments/rigla.pickle')
etalon = load_diarization('segments/rigla_etalon.pickle')

# %%
segments2 = list(read_diarization('lium/sound.xml.g.seg'))

# %%
plot_segments(sound, segments2, etalon)

# %% [markdown]
# # Расшифровка

# %%
# %run -n main.py

# %%
# transcript = list(transcribe_segments(sound, etalon))
# dump_segments_transcript(transcript, 'transcripts/rigma.pickle')
load_segments_transcript('transcripts/rigma.pickle')
# Out:
# [(Segment(start=0, stop=1.9, speaker='S0', gender='F'),
#   [Option(text="Оператор анастасия слушала", confidence=0.55),
#    Option(text="Оператор анастасия слышала", confidence=0.0),
#    Option(text="Оператор анастасия вас", confidence=0.0),
#    Option(text="Оператор анастасия слушай", confidence=0.0),
#    Option(text="Оператор анастасия хорошего", confidence=0.0)]),
#  (Segment(start=2.1, stop=8.7, speaker='S1', gender='M'),
#   [Option(text="Добрый вечер разрешены хотел бы уточнить наличие лекарства в аптеке рядом",
#           confidence=0.53),
#    Option(text="Добрый вечер результат хотел бы уточнить наличие лекарства в аптеке рядом",
#           confidence=0.0),
#    Option(text="Добрый вечер разрешат хотел бы уточнить наличие лекарства в аптеке рядом",
#           confidence=0.0),
#    Option(text="Вечер разрешены хотел бы уточнить наличие лекарства в аптеке рядом",
#           confidence=0.0),
# ...
